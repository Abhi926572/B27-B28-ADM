# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi926572/B27-B28-ADM/blob/main/Lab_6_scores_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("scores.csv")
data.sample(5)
# Out:
#     Emotional_Quotient  Intelligence_Quotient  Marks
# 13                  73                    151     74
# 66                  79                    136     85
# 63                  68                    128     73
# 15                  82                    189     85
# 59                  82                    130     84

# %%
data.describe()
data.shape
# Out:
# (80, 3)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.histplot(data['Emotional_Quotient'])
# Out:
# <Axes: xlabel='Emotional_Quotient', ylabel='Count'>

# %%
plt.subplot(1,3,2)
sns.histplot(data['Intelligence_Quotient'])
# Out:
# <Axes: xlabel='Intelligence_Quotient', ylabel='Count'>

# %%
plt.subplot(1,3,3)
sns.histplot(data['Marks'])
plt.show()

# %%
z_score_upper_limit=data['Emotional_Quotient'].mean()+3*data['Emotional_Quotient'].std()
z_score_lower_limit=data['Emotional_Quotient'].mean()-3*data['Emotional_Quotient'].std()
z_score_upper_limit
z_score_lower_limit
# Out:
# 53.108946316436615

# %%
data["Emotional_Quotient"]=np.where(
    data["Emotional_Quotient"]>z_score_upper_limit,
    z_score_upper_limit,np.where(
        data["Emotional_Quotient"]<z_score_lower_limit,
        z_score_lower_limit,
        data["Emotional_Quotient"]
        )
    )
data.describe()
# Out:
#        Emotional_Quotient  Intelligence_Quotient       Marks
# count           80.000000              80.000000   80.000000
# mean            73.163862             145.262500   76.062500
# std              6.543434              21.560479    9.195959
# min             53.108946             120.000000   45.000000
# 25%             68.000000             130.000000   72.000000
# 50%             73.000000             135.000000   76.000000
# 75%             78.000000             160.250000   81.250000
# max             92.000000             215.000000  100.000000

# %%
sns.boxplot(data["Emotional_Quotient"])
data["Intelligence_Quotient"].skew()
sns.boxplot(data["Intelligence_Quotient"])
# Out:
# <Axes: ylabel='Emotional_Quotient'>

# %%
percentile25=data["Intelligence_Quotient"].quantile(0.25)
percentile75=data["Intelligence_Quotient"].quantile(0.75)

# %%
percentile75
iqr=percentile75-percentile25
iqr
# Out:
# 30.25

# %%
iqr_upper_limit=percentile75+1.5*iqr
iqr_lower_limit=percentile25-1.5*iqr
print("Upper Limit",iqr_upper_limit)
print("Lower Limit",iqr_lower_limit)
data[data["Intelligence_Quotient"]>iqr_upper_limit]
data[data["Intelligence_Quotient"]<iqr_lower_limit]
# Out:
# Upper Limit 205.625
# Lower Limit 84.625
# Empty DataFrame
# Columns: [Emotional_Quotient, Intelligence_Quotient, Marks]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Emotional_Quotient']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Emotional_Quotient'}, axis=1)
#               .sort_values('Emotional_Quotient', ascending=True))
#   xs = counted['Emotional_Quotient']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_1.sort_values('Emotional_Quotient', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Emotional_Quotient')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Intelligence_Quotient']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Intelligence_Quotient'}, axis=1)
#               .sort_values('Intelligence_Quotient', ascending=True))
#   xs = counted['Intelligence_Quotient']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('Intelligence_Quotient', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Intelligence_Quotient')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Marks']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Marks'}, axis=1)
#               .sort_values('Marks', ascending=True))
#   xs = counted['Marks']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('Marks', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Marks')
# _ = plt.ylabel('count()')

# %%
data["Intelligence_Quotient"]=np.where(
    data["Intelligence_Quotient"]>iqr_upper_limit,
    iqr_upper_limit,
    np.where(data["Intelligence_Quotient"]<iqr_lower_limit,
    iqr_lower_limit,
    data["Intelligence_Quotient"]
             ))
data.describe()
sns.boxplot(data['Intelligence_Quotient'])
# Out:
# <Axes: ylabel='Intelligence_Quotient'>
